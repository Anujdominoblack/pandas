# %%
import pandas as pd

# %%
csv_1 = pd.read_csv("debt.csv")

# %%
csv_1
# Out:
#     year  debt
# 0   1950    26
# 1   1951    25
# 2   1952    26
# 3   1953    24
# 4   1954    24
# ..   ...   ...
# 68  2018    44
# 69  2019    46
# 70  2020    55
# 71  2021    54
# 72  2022    55
#
# [73 rows x 2 columns]

# %%
# now to get a single row

# %%
csv_2 = pd.read_csv("debt.csv",nrows=10)

# %%
csv_2
# Out:
#    year  debt
# 0  1950    26
# 1  1951    25
# 2  1952    26
# 3  1953    24
# 4  1954    24
# 5  1955    29
# 6  1956    24
# 7  1957    27
# 8  1958    23
# 9  1959    33

# %%
# now to get a particular coloumn

# %%
csv_2 = pd.read_csv("debt.csv",usecols=['year','debt'])  # write all the coloumns you want to use

# %%
csv_2
# Out:
#     year  debt
# 0   1950    26
# 1   1951    25
# 2   1952    26
# 3   1953    24
# 4   1954    24
# ..   ...   ...
# 68  2018    44
# 69  2019    46
# 70  2020    55
# 71  2021    54
# 72  2022    55
#
# [73 rows x 2 columns]

# %%
csv_3 = pd.read_csv("debt.csv",nrows=15,usecols=["year","debt"])

# %%
csv_3
# Out:
#     year  debt
# 0   1950    26
# 1   1951    25
# 2   1952    26
# 3   1953    24
# 4   1954    24
# 5   1955    29
# 6   1956    24
# 7   1957    27
# 8   1958    23
# 9   1959    33
# 10  1960    34
# 11  1961    36
# 12  1962    36
# 13  1963    35
# 14  1964    33

# %%
# we can use coloumn index also

# %%
csv_4 = pd.read_csv("debt.csv",usecols=[0])
csv_4
# Out:
#     year
# 0   1950
# 1   1951
# 2   1952
# 3   1953
# 4   1954
# ..   ...
# 68  2018
# 69  2019
# 70  2020
# 71  2021
# 72  2022
#
# [73 rows x 1 columns]

# %%
# now to skp any row

# %%
csv_5 = pd.read_csv("debt.csv",skiprows=[0,3])
csv_5 # we have skipped zero and 3rd row
# Out:
#     1950  26
# 0   1951  25
# 1   1953  24
# 2   1954  24
# 3   1955  29
# 4   1956  24
# ..   ...  ..
# 66  2018  44
# 67  2019  46
# 68  2020  55
# 69  2021  54
# 70  2022  55
#
# [71 rows x 2 columns]

# %%
# now for the header

# %%
# now to make something else header

# %%
csv_6 = pd.read_csv("debt.csv",header=2) # it makes 2nd row the header of the data
csv_6
# Out:
#     1951  25
# 0   1952  26
# 1   1953  24
# 2   1954  24
# 3   1955  29
# 4   1956  24
# ..   ...  ..
# 66  2018  44
# 67  2019  46
# 68  2020  55
# 69  2021  54
# 70  2022  55
#
# [71 rows x 2 columns]

# %%
# use of name parameter

# %%
csv_7 = pd.read_csv("debt.csv",names=["col1","col2","col3"])
csv_7  # name paramter changes the heading of each coloumn as we can see that
# Out:
#     col1  col2  col3
# 0   year  debt   NaN
# 1   1950    26   NaN
# 2   1951    25   NaN
# 3   1952    26   NaN
# 4   1953    24   NaN
# ..   ...   ...   ...
# 69  2018    44   NaN
# 70  2019    46   NaN
# 71  2020    55   NaN
# 72  2021    54   NaN
# 73  2022    55   NaN
#
# [74 rows x 3 columns]

# %%
# if heading is not there

# %%
# we will first remove and then add the heading

# %%
csv_9 = pd.read_csv("debt.csv",header=None,prefix="col")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_26864\2442637917.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   csv_9 = pd.read_csv("debt.csv",header=None,prefix="col")

# %%
csv_9  # now we can use preix to add header
# Out:
#     col0  col1
# 0   year  debt
# 1   1950    26
# 2   1951    25
# 3   1952    26
# 4   1953    24
# ..   ...   ...
# 69  2018    44
# 70  2019    46
# 71  2020    55
# 72  2021    54
# 73  2022    55
#
# [74 rows x 2 columns]
